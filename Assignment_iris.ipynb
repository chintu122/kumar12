# %%
import pandas as pd
import seaborn as sns

# %%
t=sns.load_dataset('iris')

# %%
t.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
t.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
tf=t.loc[:,['sepal_length','sepal_width','petal_length','petal_width','species']]
tf.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
tf.shape
# Out:
# (150, 5)

# %%
tf.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
ag=tf.sepal_width.mean()
round(ag,2)
# Out:
# 3.06

# %%
# handle missing values
# to fill nan value use fillna() from pandas
tf.sepal_width.fillna(3.06,inplace=True)

# %%
tf.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
inp=tf.iloc[:,1:]
inp[:2]
# Out:
#    sepal_width  petal_length  petal_width species
# 0          3.5           1.4          0.2  setosa
# 1          3.0           1.4          0.2  setosa

# %%
out=tf.sepal_length
out[:2]
# Out:
# 0    5.1
# 1    4.9
# Name: sepal_length, dtype: float64

# %%
from sklearn.naive_bayes import GaussianNB,BernoulliNB,MultinomialNB

# %%
gnb = GaussianNB()
gnb.fit(inp,out)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-8f770f5db4d2> in <cell line: 2>()
#       1 gnb = GaussianNB()
# ----> 2 gnb.fit(inp,out)
#       3
#
# /usr/local/lib/python3.10/dist-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     265         self._validate_params()
#     266         y = self._validate_data(y=y)
# --> 267         return self._partial_fit(
#     268             X, y, np.unique(y), _refit=True, sample_weight=sample_weight
#     269         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/naive_bayes.py in _partial_fit(self, X, y, classes, _refit, sample_weight)
#     425             self.classes_ = None
#     426
# --> 427         first_call = _check_partial_fit_first_call(self, classes)
#     428         X, y = self._validate_data(X, y, reset=first_call)
#     429         if sample_weight is not None:
#
# ...

# %%
tf[56:57]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 56           6.3          3.3           4.7          1.6  versicolor

# %%
tf
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
