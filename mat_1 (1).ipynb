# %%
import numpy as np
import pandas as pd

# %%
path = 'https://raw.githubusercontent.com/hakimyameen/Datasets/main/CO2%20Emissions_Canada.csv'
path
# Out:
# 'https://raw.githubusercontent.com/hakimyameen/Datasets/main/CO2%20Emissions_Canada.csv'

# %%
df = pd.read_csv(path)
df.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# ...

# %% [markdown]
# https://www.geeksforgeeks.org/univariate-bivariate-and-multivariate-data-and-its-analysis/

# %% [markdown]
# # Line plot
# - Univariate,Bivariate,Multivariate
# - When we need to trace patterns,trends over the period
# - Ex. Stock market

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
# Univariate plot
import matplotlib.pyplot as plt
# pyplot is submodule for 2D plottings

# %%
plt.plot(df['Fuel Consumption City (L/100 km)'])

# %%
plt.plot(df['CO2 Emissions(g/km)'])

# %%
plt.plot([20,60,10,150])

# %%
# groupby Cylinders
data = df.groupby('Cylinders')['CO2 Emissions(g/km)'].mean()
data
# Out:
# Cylinders
# 3     174.894737
# 4     204.859938
# 5     235.692308
# 6     263.446852
# 8     320.619116
# 10    361.309524
# 12    381.033113
# 16    522.000000
# Name: CO2 Emissions(g/km), dtype: float64

# %%
plt.plot(data,marker='*',color='red',linestyle='--',label='Co2 Emission/cyl')
#plt.text(3,180,'Pallavi')
for x,y in zip(data.index,data.values):

    label = "{:.2f}".format(y)

    plt.annotate(label, # this is the text
                 (x,y), # these are the coordinates to position the label
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center')
plt.legend()

# %%
plt.plot(data,marker='*',color='red',linestyle='--',label='Co2 Emission/cyl')
plt.title('Co2 Emission per Cylinder')
plt.xlabel('Cylinders')
plt.ylabel('CO2 Emission')
plt.grid()
plt.legend()

# to save the plot
plt.savefig('p.jpg')

# %%
#
df.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
data2 = df.groupby('Cylinders')['Fuel Consumption City (L/100 km)'].mean()
data2
# assignment: Combine 3 plots  for
# 'Fuel Consumption City (L/100 km)','Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)'
# Out:
# Cylinders
# 3      8.345263
# 4      9.906646
# 5     11.750000
# 6     13.262469
# 8     16.748217
# 10    18.216667
# 12    19.641060
# 16    26.800000
# Name: Fuel Consumption City (L/100 km), dtype: float64

# %%
# combine multiple line plots
plt.plot([10,22,3,45],label='plot_1') #plot 1

plt.plot([2,40,16,33],label='plot_2') #plot 2

plt.legend()

# %%
# separate 2 plot: one after another
plt.plot([10,22,3,45],label='plot_1') #plot 1
plt.legend()
plt.show()

plt.plot([2,40,16,33],label='plot_2') #plot 2
plt.ylim((1,50))
plt.legend()
plt.show()

# %% [markdown]
# ## Bivariate line plot

# %%
df['Fuel Type'].nunique()
# Out:
# 5

# %%
data3 = df.groupby('Fuel Type')['CO2 Emissions(g/km)'].mean()
data3
# Out:
# Fuel Type
# D    237.548571
# E    275.091892
# N    213.000000
# X    235.119329
# Z    266.043410
# Name: CO2 Emissions(g/km), dtype: float64

# %%
#separate x and y values
x = data3.index
x
# Out:
# Index(['D', 'E', 'N', 'X', 'Z'], dtype='object', name='Fuel Type')

# %%
y = data3.values
y
# Out:
# array([237.54857143, 275.09189189, 213.        , 235.11932912,
#        266.04341037])

# %%
plt.plot(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
# prompt:  assignment: Combine 3 plots  for # 'Fuel Consumption City (L/100 km)','Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)'

df.plot(kind='line', x='Cylinders', y=['Fuel Consumption City (L/100 km)', 'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)'])
plt.title('Fuel Consumption by Cylinder Count')
plt.xlabel('Cylinders')
plt.ylabel('Fuel Consumption (L/100 km)')
plt.legend()
plt.show()
